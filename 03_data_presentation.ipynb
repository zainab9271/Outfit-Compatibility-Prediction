# %% [markdown]
# <a href="https://colab.research.google.com/github/zainab9271/Outfit-Compatibility-Prediction/blob/main/03_data_presentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import Libraries

# %%
import pandas as pd

# %% [markdown]
# # Data for Outfit Compatibility Task

# %% [markdown]
# ## Train Data

# %%
compatibility_train_df = pd.read_csv('/content/drive/MyDrive/Outfit_Recommendation_Project/Data_CSV_Files/modified_disjoint_compatibility_train.csv')
compatibility_train_df
# Out:
#        compatibility                                      outfit_sample
# 0                  1        ['224926512_1','224926512_2','224926512_7']
# 1                  0  ['217618045_5','221129424_3','219519448_1','22...
# 2                  1        ['224942316_1','224942316_2','224942316_3']
# 3                  0        ['221690606_2','201817930_1','225326438_4']
# 4                  1        ['221204003_1','221204003_2','221204003_5']
# ...              ...                                                ...
# 30509              0        ['203874358_2','222948312_4','222608343_1']
# 30510              1        ['225055666_1','225055666_2','225055666_4']
# 30511              1  ['181784999_1','181784999_2','181784999_3','18...
# 30512              0  ['216803761_3','223866887_2','191636459_3','21...
# 30513              0  ['205239388_6','85133840_4','80193007_2','2165...
#
# [30514 rows x 2 columns]

# %%
compatibility_train_df.compatibility.hist()

# %%
train_outfits_images_df = pd.read_csv('/content/drive/MyDrive/Outfit_Recommendation_Project/Data_CSV_Files/disjiont_train_outfits_images.csv')
train_outfits_images_df
# Out:
#       outfits_images_id                                outfits_images_path
# 0           199244701_1  /content/content/polyvore_outfits/images/13262...
# 1           199244701_2  /content/content/polyvore_outfits/images/15396...
# 2           199244701_3  /content/content/polyvore_outfits/images/17116...
# 3           199244701_4  /content/content/polyvore_outfits/images/16279...
# 4           199244701_5  /content/content/polyvore_outfits/images/17253...
# ...                 ...                                                ...
# 85930       205613256_4  /content/content/polyvore_outfits/images/17596...
# 85931       205613256_5  /content/content/polyvore_outfits/images/16292...
# 85932       205613256_6  /content/content/polyvore_outfits/images/18060...
# 85933       225327855_1  /content/content/polyvore_outfits/images/18038...
# 85934       225327855_2  /content/content/polyvore_outfits/images/20191...
#
# [85935 rows x 2 columns]

# %% [markdown]
# ## Test Data

# %%
compatibility_test_df = pd.read_csv('/content/drive/MyDrive/Outfit_Recommendation_Project/Data_CSV_Files/modified_disjoint_compatibility_test.csv')
compatibility_test_df
# Out:
#        compatibility                                      outfit_sample
# 0                  0  ['209641731_2','75506832_1','178226644_5','222...
# 1                  1           ['91600883_1','91600883_3','91600883_4']
# 2                  1        ['197097038_1','197097038_2','197097038_5']
# 3                  1  ['223956352_1','223956352_2','223956352_3','22...
# 4                  0        ['210494218_3','213683809_3','224374679_1']
# ...              ...                                                ...
# 25847              0  ['177365168_3','205390279_2','73786162_7','881...
# 25848              1        ['184932845_1','184932845_2','184932845_4']
# 25849              1  ['217259885_1','217259885_2','217259885_4','21...
# 25850              0  ['171610220_4','75326151_4','207600483_2','202...
# 25851              0  ['181614947_2','34353094_7','167750960_2','181...
#
# [25852 rows x 2 columns]

# %%
test_outfits_images_df = pd.read_csv('/content/drive/MyDrive/Outfit_Recommendation_Project/Data_CSV_Files/disjiont_test_outfits_images.csv')
test_outfits_images_df
# Out:
#       outfits_images_id                             outfits_images_path
# 0           222049137_1  /content/polyvore_outfits/images/159402796.jpg
# 1           222049137_2  /content/polyvore_outfits/images/200810877.jpg
# 2           222049137_3  /content/polyvore_outfits/images/208881110.jpg
# 3           222049137_4  /content/polyvore_outfits/images/208898299.jpg
# 4           222049137_5  /content/polyvore_outfits/images/176837161.jpg
# ...                 ...                                             ...
# 74257        42911078_7   /content/polyvore_outfits/images/39806532.jpg
# 74258       210601169_1  /content/polyvore_outfits/images/189120927.jpg
# 74259       210601169_2  /content/polyvore_outfits/images/189120433.jpg
# 74260       210601169_3  /content/polyvore_outfits/images/189121156.jpg
# 74261       210601169_4  /content/polyvore_outfits/images/189120712.jpg
#
# [74262 rows x 2 columns]
# ...

# %% [markdown]
# ## Valid Data

# %%
compatibility_valid_df = pd.read_csv('/content/drive/MyDrive/Outfit_Recommendation_Project/Data_CSV_Files/disjoint_compatibility_valid_outfits.csv')
compatibility_valid_df.sample(10)
# Out:
#       compatibility                                      outfit_sample
# 3965              0  ['202622471_2', '210521614_3', '202691468_4', ...
# 5927              0  ['225322853_1', '164138480_2', '221797947_3', ...
# 1882              1  ['225284839_1', '225284839_2', '225284839_3', ...
# 1518              1  ['162387302_1', '162387302_2', '162387302_3', ...
# 1955              1  ['208748953_1', '208748953_2', '208748953_3', ...
# 5139              0  ['195007876_2', '219275868_3', '222480180_4', ...
# 4916              0  ['224561356_4', '220148265_4', '223755359_7', ...
# 5663              0  ['220020518_1', '207503552_2', '223999625_3', ...
# 3593              0  ['221698280_1', '76146160_2', '208906753_4', '...
# 2719              1      ['221956796_1', '221956796_2', '221956796_3']

# %%
valid_outfits_images_df = pd.read_csv('/content/drive/MyDrive/Outfit_Recommendation_Project/Data_CSV_Files/disjiont_valid_outfits_images.csv')
valid_outfits_images_df
# Out:
#       outfits_images_id                             outfits_images_path
# 0           223648758_1  /content/polyvore_outfits/images/211863963.jpg
# 1           223648758_2  /content/polyvore_outfits/images/211794495.jpg
# 2           223648758_3  /content/polyvore_outfits/images/187542135.jpg
# 3           223648758_4  /content/polyvore_outfits/images/212083222.jpg
# 4           223648758_5  /content/polyvore_outfits/images/210919977.jpg
# ...                 ...                                             ...
# 15283       198313686_6  /content/polyvore_outfits/images/167686306.jpg
# 15284       223051514_1  /content/polyvore_outfits/images/189281917.jpg
# 15285       223051514_2  /content/polyvore_outfits/images/201824722.jpg
# 15286       223051514_3  /content/polyvore_outfits/images/144313692.jpg
# 15287       223051514_4  /content/polyvore_outfits/images/178616448.jpg
#
# [15288 rows x 2 columns]

# %% [markdown]
# # Data for Outfit Complementary Item Retrieval Task

# %% [markdown]
# ## Train Data

# %%
fill_blank_train_df = pd.read_csv('/content/drive/MyDrive/Outfit_Recommendation_Project/Data_CSV_Files/disjoint_fill_blank_train_outfits.csv')
fill_blank_train_df.sample(10)
# Out:
#                                                 question  blank_position  \
# 2474   ['73796719_1', '73796719_2', '73796719_3', '73...               6
# 14239                     ['184949437_1', '184949437_3']               2
# 4713   ['225045192_1', '225045192_2', '225045192_3', ...               4
# 7879   ['215321383_1', '215321383_3', '215321383_4', ...               2
# 2907       ['221026617_2', '221026617_3', '221026617_4']               1
# 11906  ['223380813_1', '223380813_2', '223380813_3', ...               5
# 4334                      ['194651590_2', '194651590_3']               1
# 13873  ['210877701_1', '210877701_2', '210877701_4', ...               3
# 10047      ['224931106_1', '224931106_2', '224931106_3']               4
# 8969   ['206262424_2', '206262424_3', '206262424_4', ...               1
#
#                                                  answers
# 2474   ['179846843_4', '196449772_3', '222028297_5', ...
# ...

# %% [markdown]
# ## Test Data

# %%
fill_blank_test_df = pd.read_csv('/content/drive/MyDrive/Outfit_Recommendation_Project/Data_CSV_Files/disjoint_fill_blank_test_outfits.csv')
fill_blank_test_df.sample(10)
# Out:
#                                                 question  blank_position  \
# 6487   ['223957425_2', '223957425_3', '223957425_4', ...               1
# 11197  ['206007080_1', '206007080_2', '206007080_3', ...               5
# 5239   ['156249274_1', '156249274_2', '156249274_3', ...               5
# 7720       ['181414236_2', '181414236_3', '181414236_4']               1
# 3374       ['201458691_1', '201458691_2', '201458691_4']               3
# 1322   ['50705065_1', '50705065_2', '50705065_3', '50...               7
# 13593  ['212698798_1', '212698798_2', '212698798_4', ...               3
# 11322  ['117485448_1', '117485448_2', '117485448_3', ...               5
# 1760   ['93014218_1', '93014218_2', '93014218_3', '93...               5
# 14741                     ['141427945_1', '141427945_2']               3
#
#                                                  answers
# 6487   ['93990380_1', '120577943_1', '223957425_1', '...
# ...

# %% [markdown]
# ## Valid Data

# %%
fill_blank_valid_df = pd.read_csv('/content/drive/MyDrive/Outfit_Recommendation_Project/Data_CSV_Files/disjoint_fill_blank_valid_outfits.csv')
fill_blank_valid_df.sample(10)
# Out:
#                                                question  blank_position  \
# 55    ['207050660_1', '207050660_2', '207050660_3', ...               5
# 2650  ['224483565_1', '224483565_2', '224483565_3', ...               5
# 2729  ['224921807_1', '224921807_2', '224921807_3', ...               6
# 201   ['191518403_1', '191518403_2', '191518403_3', ...               4
# 2282      ['224213819_2', '224213819_3', '224213819_4']               1
# 1486  ['222894768_1', '222894768_2', '222894768_4', ...               3
# 292       ['205869685_1', '205869685_2', '205869685_4']               3
# 1037  ['211868939_2', '211868939_3', '211868939_4', ...               1
# 341   ['219527306_1', '219527306_2', '219527306_4', ...               3
# 61    ['96163130_1', '96163130_2', '96163130_4', '96...               3
#
#                                                 answers
# 55    ['155114686_4', '207050660_5', '131067974_6', ...
# 2650  ['224483565_5', '122724882_6', '158571000_6', ...
# ...
